# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
Date = datetime.today().strftime('%Y-%m-%d')
Date = str(datetime.strptime('2020-07-24', '%Y-%m-%d').date())

# %%
url = 'https://www.pencilnews.cn/journalist/1535539.html'
source = r.get(url).text
source
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />\n    <!--<meta name="apple-itunes-app" content="app-id=1179761595">-->\n    <meta name="baidu-site-verification" content="XzDsKwXKLB" />\n    <meta name="format-detection" content="telephone=no">\n    <meta name="format-detection" content="address=no">\n    <meta name="msvalidate.01" content="221C2BA206DD2C1D975EB3F81DE44ACD" />\n    <meta name=\'keywords\' Content=\'\'>\n    <meta name=\'author\' Content=\'\'>\n    <meta name=\'description\' Content=\'\'>\n    <meta property=\'og:type\' content="">\n    <meta property=\'og:title\' content=\'\'>\n    <meta property=\'og:description\' content="">\n    <meta property=\'og:url\' content=\'\'>\n    <meta name="360-site-verification" content="c0efc5369d10fe4d647af23d4591cd87" />\n    <meta name="baid
# ...

# %%
News = BeautifulSoup(source,'html')
News
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <!--<meta name="apple-itunes-app" content="app-id=1179761595">-->
# <meta content="XzDsKwXKLB" name="baidu-site-verification"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <meta content="221C2BA206DD2C1D975EB3F81DE44ACD" name="msvalidate.01"/>
# <meta content="" name="keywords"/>
# <meta content="" name="author"/>
# <meta content="" name="description"/>
# <meta content="" property="og:type"/>
# <meta content="" property="og:title"/>
# <meta content="" property="og:description"/>
# <meta content="" property="og:url"/>
# <meta content="c0efc5369d10fe4d647af23d4591cd87" name="360-site-verification"/>
# <meta content="4IbCcGODwt" name="baidu-site-verification"/>
# ...

# %%
newslist = News.find('div', {"id": "articles_list_container"}).find('div', {"id": "artciles_field"})
newslist
# Out:
# <div id="artciles_field" pagenum="1">
# <div class="article_block">
# <div class="article_img">
# <a href="/p/37968.html?from=article_list" target="_blank">
# <img alt="新能源汽车扎堆商圈背后的商业逻辑" class="img-responsive" onerror="this.src='/imgs/qianbidao.png'" src="https://cdn.pencilnews.cn/library/1535539/ea87e2c12238ada56c92e2e2ab135518.jpg?imageView2/2/w/500/h/500/q/75"/>
# </a>
# </div>
# <div class="article_content">
# <h3>
# <a href="/p/37968.html?from=article_list" target="_blank">新能源汽车扎堆商圈背后的商业逻辑</a>
# </h3>
# <div class="article_digest">
# <a href="/p/37968.html?from=article_list" target="_blank">
# <span>商圈成了造车新势力的必争之地。</span>
# </a>
# </div>
# <div class="article_author">
# <div>
# <span class="cate-tag">圈内热点</span>
# </div>
# <div class="author_items">
# <a class="author_name" style="color: #9b9b9b">
# <span>锌刻度</span>
# </a>
# <span>2020-07-24</span>
# </div>
# </div>
# </div>
# </div>
# <div class="article_block">
# <div class="article_img">
# ...

# %%
title = newslist.find('div', class_='article_block').find('div', class_='article_content').find('a').text
title
# Out:
# '新能源汽车扎堆商圈背后的商业逻辑'

# %%
link = newslist.find('div', class_='article_block').find('div', class_='article_content').find('a')['href']
newslink = 'pencilnews.cn' + link
newslink
# Out:
# 'pencilnews.cn/p/37968.html?from=article_list'

# %%
author = newslist.find('div', class_='article_block').find('div', class_='article_content').find('div', class_='author_items').find('a', class_='author_name').text.strip()
author
# Out:
# '锌刻度'

# %%
newsdate = newslist.find('div', class_='article_block').find('div', class_='article_content').find('div', class_='author_items').text.strip()[5:]
newsdate
# Out:
# '2020-07-24'

# %%
df = pd.DataFrame(columns=['Title', 'Author', 'Dates', 'Links'])
Editor = ["罗蔓"]
i = 0
for i in range(0,len(newslist)):
    if newsdate == Date and author == Editor:
        title = newslist[i].find('div', class_='article_block').find('div', class_='article_content').find('a').text
        author = newslist[i].find('div', class_='article_block').find('div', class_='article_content').find('div', class_='author_items').find('a', class_='author_name').text.strip()
        newsdate = newslist[i].find('div', class_='article_block').find('div', class_='article_content').find('div', class_='author_items').text.strip()[5:]
        link = newslist[i].find('div', class_='article_block').find('div', class_='article_content').find('a')['href']
        newslink = 'pencilnews.cn' + link
        i = i + 1
    df = df.append({'Title':title, 'Author': author, 'Dates': newsdate, 'Links': newslink},ignore_index=True)
    print(df)
# Out:
#               Title Author       Dates  \
# 0  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
#
#                                           Links
# 0  pencilnews.cn/p/37968.html?from=article_list
#               Title Author       Dates  \
# 0  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
# 1  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
#
#                                           Links
# 0  pencilnews.cn/p/37968.html?from=article_list
# 1  pencilnews.cn/p/37968.html?from=article_list
#               Title Author       Dates  \
# 0  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
# 1  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
# 2  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
#
#                                           Links
# 0  pencilnews.cn/p/37968.html?from=article_list
# 1  pencilnews.cn/p/37968.html?from=article_list
# 2  pencilnews.cn/p/37968.html?from=article_list
#               Title Author       Dates  \
# 0  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
# 1  新能源汽车扎堆商圈背后的商业逻辑    锌刻度  2020-07-24
# ...
